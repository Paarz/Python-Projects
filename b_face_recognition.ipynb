# %% [markdown]
# <a href="https://colab.research.google.com/github/Paarz/Python-Projects/blob/main/b_face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dlib
# !pip install face-recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import face_recognition
import numpy as np

# %%
image = face_recognition.load_image_file("/content/bo1.jpg")

# %%
import cv2
from google.colab.patches import cv2_imshow
#cv2_imshow("Image", cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#cv2.waitKey(0)
image = cv2.imread("/content/bo1.jpg")
#lane_image = np.copy(image)
#gray = cv2.cvtColor(lane_image, cv2.COLOR_RGB2GRAY)

cv2_imshow(image)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F150E63FB80>
# -1

# %%
# Face Detection
import cv2
from google.colab.patches import cv2_imshow
face_locations = face_recognition.face_locations(image)

for (top, right, bottom, left) in face_locations:
    # Draw a box around the face
    cv2.rectangle(image, (left, top), (right, bottom), (0, 255, 0), 2)


cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F14C1DC3C70>
# -1

# %%
# Facial Landmarks Detection
face_landmarks_list = face_recognition.face_landmarks(image)

facial_features = [
        'chin',
        'left_eyebrow',
        'right_eyebrow',
        'nose_bridge',
        'nose_tip',
        'left_eye',
        'right_eye',
        'top_lip',
        'bottom_lip']


for face_landmarks in face_landmarks_list:
    for facial_feature in facial_features:
        for point in face_landmarks[facial_feature]:
            image = cv2.circle(image, point, 2, (255,60,170),2)
            
            
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F14C1DDE460>
# -1

# %%
# Face Recognition
image = face_recognition.load_image_file("/content/bo1.jpg")
#unknown_image = face_recognition.load_image_file("C:/Users/nhoei/barackObama2.jpg")
#unknown_image = face_recognition.load_image_file("C:/Users/nhoei/elonMusk.jpg")
unknown_image = face_recognition.load_image_file("/content/sp1.jpg")

image_encoding = face_recognition.face_encodings(image)[0]
unknown_encoding = face_recognition.face_encodings(unknown_image)[0]

results = face_recognition.compare_faces([image_encoding], unknown_encoding)
results
# Out:
# [False]

# %%
# Out:
# Barack Obama

# %%
#results = face_recognition.compare_faces([image_encoding], unknown_encoding)
from google.colab.patches import cv2_imshow
import cv2
#cv2.putText(unknown_image, f'Barack Obama: {results[0]}', (25,75), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 1)
cv2_imshow(image)
print("Barack Obama")
cv2_imshow(unknown_image)
if results==[True]:
  print("Barack Obama")
else:
    print("Unknown")
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F14C1DCF160>
# Barack Obama
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F14C1DCFE20>
# Unknown
# -1
