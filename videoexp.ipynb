# %% [markdown]
# <a href="https://colab.research.google.com/github/Paarz/Python-Projects/blob/main/videoexp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2     # for capturing videos
import math   # for mathematical operations
import matplotlib.pyplot as plt    # for plotting the images
# %matplotlib inline
import pandas as pd
from keras.preprocessing import image   # for preprocessing the images
import numpy as np    # for mathematical operations
from keras.utils import np_utils
from skimage.transform import resize   # for resizing images

# %%
bo1 = cv2.VideoCapture('/content/bovc1.mp4')
bo1
# Out:
# < cv2.VideoCapture 0x7f3a2d7c3830>

# %%
# Importing all necessary libraries
import cv2
import os

# Read the video from specified path
bovc1f = cv2.VideoCapture("/content/bovc1.mp4")

try:
	
	# creating a folder named data
	if not os.path.exists('data'):
		os.makedirs('data')

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

# frame
currentframe = 0

while(True):
	
	# reading from frame
	ret,frame = bovc1f.read()

	if ret:
		# if video is still left continue creating images
		name = './data/frame' + str(currentframe) + '.jpg'
		print ('Creating...' + name)

		# writing the extracted images
		cv2.imwrite(name, frame)

		# increasing counter so that it will
		# show how many frames are created
		currentframe += 1
	else:
		break

# Release all space and windows once done
bovc1f.release()
cv2.destroyAllWindows()
# Out:
# Creating..../data/frame0.jpg
# Creating..../data/frame1.jpg
# Creating..../data/frame2.jpg
# Creating..../data/frame3.jpg
# Creating..../data/frame4.jpg
# Creating..../data/frame5.jpg
# Creating..../data/frame6.jpg
# Creating..../data/frame7.jpg
# Creating..../data/frame8.jpg
# Creating..../data/frame9.jpg
# Creating..../data/frame10.jpg
# Creating..../data/frame11.jpg
# Creating..../data/frame12.jpg
# Creating..../data/frame13.jpg
# Creating..../data/frame14.jpg
# Creating..../data/frame15.jpg
# Creating..../data/frame16.jpg
# Creating..../data/frame17.jpg
# Creating..../data/frame18.jpg
# Creating..../data/frame19.jpg
# Creating..../data/frame20.jpg
# Creating..../data/frame21.jpg
# Creating..../data/frame22.jpg
# Creating..../data/frame23.jpg
# Creating..../data/frame24.jpg
# Creating..../data/frame25.jpg
# Creating..../data/frame26.jpg
# Creating..../data/frame27.jpg
# Creating..../data/frame28.jpg
# Creating..../data/frame29.jpg
# Creating..../data/frame30.jpg
# ...

# %%
img = plt.imread('/content/data/frame104.jpg')   # reading image using its name
plt.imshow(img)

# %%
#success,image=bo1.read()
#image

# %%
#from PIL import Image
#im = Image.fromarray(image)
#im.save("ima1.jpeg")
#im.show()

# %%
#img = plt.imread('ima1.jpeg')   # reading image using its name
#plt.imshow(img)

# %%
#colourImg = Image.open("ima1.jpeg")
#colourPixels = colourImg.convert("RGB")
#colourArray = np.array(colourPixels.getdata())

#df = pd.DataFrame(colourArray, columns=["red","green","blue"])
#df

# %%
# Importing all necessary libraries for second video trainset of Barack Obama 
import cv2
import os

# Read the video from specified path
bovc2f = cv2.VideoCapture("/content/bovc2.mp4")

try:
	
	# creating a folder named data
	if not os.path.exists('dataob2'):
		os.makedirs('dataob2')

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

# frame
currentframeb2 = 0

while(True):
	
	# reading from frame
	retb2,frameb2 = bovc2f.read()

	if retb2:
		# if video is still left continue creating images
		nameb2 = './dataob2/frameb2' + str(currentframeb2) + '.jpg'
		print ('Creating...' + nameb2)

		# writing the extracted images
		cv2.imwrite(nameb2, frameb2)

		# increasing counter so that it will
		# show how many frames are created
		currentframeb2 += 1
	else:
		break

# Release all space and windows once done
bovc2f.release()
cv2.destroyAllWindows()
# Out:
# Creating..../dataob2/frameb20.jpg
# Creating..../dataob2/frameb21.jpg
# Creating..../dataob2/frameb22.jpg
# Creating..../dataob2/frameb23.jpg
# Creating..../dataob2/frameb24.jpg
# Creating..../dataob2/frameb25.jpg
# Creating..../dataob2/frameb26.jpg
# Creating..../dataob2/frameb27.jpg
# Creating..../dataob2/frameb28.jpg
# Creating..../dataob2/frameb29.jpg
# Creating..../dataob2/frameb210.jpg
# Creating..../dataob2/frameb211.jpg
# Creating..../dataob2/frameb212.jpg
# Creating..../dataob2/frameb213.jpg
# Creating..../dataob2/frameb214.jpg
# Creating..../dataob2/frameb215.jpg
# Creating..../dataob2/frameb216.jpg
# Creating..../dataob2/frameb217.jpg
# Creating..../dataob2/frameb218.jpg
# Creating..../dataob2/frameb219.jpg
# Creating..../dataob2/frameb220.jpg
# Creating..../dataob2/frameb221.jpg
# Creating..../dataob2/frameb222.jpg
# Creating..../dataob2/frameb223.jpg
# Creating..../dataob2/frameb224.jpg
# Creating..../dataob2/frameb225.jpg
# Creating..../dataob2/frameb226.jpg
# ...

# %%
img2 = plt.imread('/content/dataob2/frameb2104.jpg')   # reading image using its name
plt.imshow(img2)

# %%
# Importing all necessary libraries for first video trainset of Narendra Modi 
import cv2
import os

# Read the video from specified path
nmv1f = cv2.VideoCapture("/content/nmv1.mp4")
try:
	
	# creating a folder named data
	if not os.path.exists('dataom1'):
		os.makedirs('datam1')

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

# frame
currentframem1 = 0

while(True):
	
	# reading from frame
	retm1,framem1 = nmv1f.read()

	if retm1:
		# if video is still left continue creating images
		namem1 = './datam1/framem1' + str(currentframem1) + '.jpg'
		print ('Creating...' + namem1)

		# writing the extracted images
		cv2.imwrite(namem1, framem1)

		# increasing counter so that it will
		# show how many frames are created
		currentframem1 += 1
	else:
		break

# Release all space and windows once done
nmv1f.release()
cv2.destroyAllWindows()
# Out:
# Error: Creating directory of data
# Creating..../datam1/framem10.jpg
# Creating..../datam1/framem11.jpg
# Creating..../datam1/framem12.jpg
# Creating..../datam1/framem13.jpg
# Creating..../datam1/framem14.jpg
# Creating..../datam1/framem15.jpg
# Creating..../datam1/framem16.jpg
# Creating..../datam1/framem17.jpg
# Creating..../datam1/framem18.jpg
# Creating..../datam1/framem19.jpg
# Creating..../datam1/framem110.jpg
# Creating..../datam1/framem111.jpg
# Creating..../datam1/framem112.jpg
# Creating..../datam1/framem113.jpg
# Creating..../datam1/framem114.jpg
# Creating..../datam1/framem115.jpg
# Creating..../datam1/framem116.jpg
# Creating..../datam1/framem117.jpg
# Creating..../datam1/framem118.jpg
# Creating..../datam1/framem119.jpg
# Creating..../datam1/framem120.jpg
# Creating..../datam1/framem121.jpg
# Creating..../datam1/framem122.jpg
# Creating..../datam1/framem123.jpg
# Creating..../datam1/framem124.jpg
# Creating..../datam1/framem125.jpg
# Creating..../datam1/framem126.jpg
# ...

# %%
img3 = plt.imread('/content/datam1/framem1104.jpg')   # reading image using its name
plt.imshow(img3)

# %%
# Importing all necessary libraries for second video trainset of Narendra Modi 
import cv2
import os

# Read the video from specified path
nmv2f = cv2.VideoCapture("/content/nmv2.mp4")
try:
	
	# creating a folder named data
	if not os.path.exists('datam2'):
		os.makedirs('datam2')

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

# frame
currentframem2 = 0

while(True):
	
	# reading from frame
	retm2,framem2 = nmv2f.read()

	if retm2:
		# if video is still left continue creating images
		namem2 = './datam2/framem2' + str(currentframem2) + '.jpg'
		print ('Creating...' + namem2)

		# writing the extracted images
		cv2.imwrite(namem2, framem2)

		# increasing counter so that it will
		# show how many frames are created
		currentframem2 += 1
	else:
		break

# Release all space and windows once done
nmv2f.release()
cv2.destroyAllWindows()
# Out:
# Creating..../datam2/framem20.jpg
# Creating..../datam2/framem21.jpg
# Creating..../datam2/framem22.jpg
# Creating..../datam2/framem23.jpg
# Creating..../datam2/framem24.jpg
# Creating..../datam2/framem25.jpg
# Creating..../datam2/framem26.jpg
# Creating..../datam2/framem27.jpg
# Creating..../datam2/framem28.jpg
# Creating..../datam2/framem29.jpg
# Creating..../datam2/framem210.jpg
# Creating..../datam2/framem211.jpg
# Creating..../datam2/framem212.jpg
# Creating..../datam2/framem213.jpg
# Creating..../datam2/framem214.jpg
# Creating..../datam2/framem215.jpg
# Creating..../datam2/framem216.jpg
# Creating..../datam2/framem217.jpg
# Creating..../datam2/framem218.jpg
# Creating..../datam2/framem219.jpg
# Creating..../datam2/framem220.jpg
# Creating..../datam2/framem221.jpg
# Creating..../datam2/framem222.jpg
# Creating..../datam2/framem223.jpg
# Creating..../datam2/framem224.jpg
# Creating..../datam2/framem225.jpg
# Creating..../datam2/framem226.jpg
# Creating..../datam2/framem227.jpg
# ...

# %%
img4 = plt.imread('/content/datam2/framem210.jpg')   # reading image using its name
plt.imshow(img4)
